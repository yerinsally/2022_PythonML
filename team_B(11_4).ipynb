# %% [markdown]
# <a href="https://colab.research.google.com/github/yerinsally/2022_PythonML/blob/main/team_B(11_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MachineLearning/data/F_Rotor.csv', encoding='utf-8')

# %%
data.head()
# Out:
#    Unnamed: 0  In_22_Size       In_22_X       In_22_Y      In_22_XP  \
# 0           0    0.263751  1.421085e-14  7.105427e-15 -9.094947e-13
# 1           1    0.160330  1.421085e-14  7.105427e-15 -9.094947e-13
# 2           2    0.056909  1.421085e-14  7.105427e-15 -9.094947e-13
# 3           3    0.108620  1.421085e-14  7.105427e-15 -9.094947e-13
# 4           4    0.160330  1.421085e-14  7.105427e-15 -9.094947e-13
#
#        In_22_YP  In_8_Size    In_8_X    In_8_Y   In_8_XP  ...    In_9_X  \
# 0  4.547474e-13   0.435124 -0.029918 -0.917867  0.001861  ...  0.566484
# 1  4.547474e-13   0.641711  0.298653  0.539664  0.327213  ...  0.166597
# 2  4.547474e-13  -0.184636  0.627224 -0.116225  0.658409  ... -0.366586
# 3  4.547474e-13  -2.043918  0.824367 -0.626361  0.827903  ...  0.499837
# 4  4.547474e-13  -0.597810 -0.949917  1.414182 -0.949841  ... -0.299938
#
#      In_9_Y   In_9_XP   In_9_YP    In_9_P   In_9_PX   In_9_PY  In_9_PXB  \
# ...

# %%
data.shape
# Out:
# (2974, 47)

# %%
data.describe() 
# In_22_X, In_22_Y, In_22_XP, In_22_YP 칼럼은 표준편차가 0이기 때문에 값이 모두 동일함
# 따라서 삭제하고 진행
# Out:
#         Unnamed: 0    In_22_Size       In_22_X       In_22_Y      In_22_XP  \
# count  2974.000000  2.974000e+03  2.974000e+03  2.974000e+03  2.974000e+03
# mean   1486.500000  9.468806e-14  1.421085e-14  7.105427e-15 -9.094947e-13
# std     858.664176  1.000168e+00  0.000000e+00  0.000000e+00  0.000000e+00
# min       0.000000 -6.355177e+00  1.421085e-14  7.105427e-15 -9.094947e-13
# 25%     743.250000 -4.084841e-01  1.421085e-14  7.105427e-15 -9.094947e-13
# 50%    1486.500000  1.086196e-01  1.421085e-14  7.105427e-15 -9.094947e-13
# 75%    2229.750000  5.223026e-01  1.421085e-14  7.105427e-15 -9.094947e-13
# max    2973.000000  9.675039e+00  1.421085e-14  7.105427e-15 -9.094947e-13
#
#            In_22_YP     In_8_Size        In_8_X        In_8_Y       In_8_XP  \
# count  2.974000e+03  2.974000e+03  2.974000e+03  2.974000e+03  2.974000e+03
# mean   4.547474e-13  1.507669e-13  1.383814e-14 -2.118918e-13 -3.189176e-13
# ...

# %%
rounded_data = round(data, 3)

# %%
rounded_data.head()
# Out:
#    Unnamed: 0  In_22_Size  In_22_X  In_22_Y  In_22_XP  In_22_YP  In_8_Size  \
# 0           0       0.264      0.0      0.0      -0.0       0.0      0.435
# 1           1       0.160      0.0      0.0      -0.0       0.0      0.642
# 2           2       0.057      0.0      0.0      -0.0       0.0     -0.185
# 3           3       0.109      0.0      0.0      -0.0       0.0     -2.044
# 4           4       0.160      0.0      0.0      -0.0       0.0     -0.598
#
#    In_8_X  In_8_Y  In_8_XP  ...  In_9_X  In_9_Y  In_9_XP  In_9_YP  In_9_P  \
# 0  -0.030  -0.918    0.002  ...   0.566  -0.511    0.554   -0.521  -0.461
# 1   0.299   0.540    0.327  ...   0.167  -0.566    0.198   -0.549  -0.715
# 2   0.627  -0.116    0.658  ...  -0.367  -0.071   -0.342   -0.082  -1.187
# 3   0.824  -0.626    0.828  ...   0.500   1.689    0.503    1.664   1.029
# 4  -0.950   1.414   -0.950  ...  -0.300   1.194   -0.283    1.170   0.302
#
#    In_9_PX  In_9_PY  In_9_PXB  In_9_PYB  decisionP
# ...

# %%
rounded_data.describe()
# 여기서도 In_22_X, In_22_Y, In_22_XP, In_22_YP 칼럼의 값이 모두 동일한 것을 확인할 수 있음
# Out:
#         Unnamed: 0   In_22_Size  In_22_X  In_22_Y  In_22_XP  In_22_YP  \
# count  2974.000000  2974.000000   2974.0   2974.0    2974.0    2974.0
# mean   1486.500000    -0.000011      0.0      0.0       0.0       0.0
# std     858.664176     1.000172      0.0      0.0       0.0       0.0
# min       0.000000    -6.355000      0.0      0.0      -0.0       0.0
# 25%     743.250000    -0.408000      0.0      0.0       0.0       0.0
# 50%    1486.500000     0.109000      0.0      0.0      -0.0       0.0
# 75%    2229.750000     0.522000      0.0      0.0      -0.0       0.0
# max    2973.000000     9.675000      0.0      0.0      -0.0       0.0
#
#          In_8_Size       In_8_X       In_8_Y      In_8_XP  ...       In_9_X  \
# count  2974.000000  2974.000000  2974.000000  2974.000000  ...  2974.000000
# mean      0.000002     0.000064     0.000030     0.000006  ...     0.000005
# std       1.000166     1.000172     1.000169     1.000169  ...     1.000152
# ...

# %%
import matplotlib.pyplot as plt
pd.DataFrame(rounded_data).hist(figsize=(20,10))  # histogram
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f97074f4bd0>,
# ...
#       dtype=object)

# %% [markdown]
# # data split

# %%
X = rounded_data.drop(["decisionP", "Unnamed: 0", "In_22_X", "In_22_Y", "In_22_XP", "In_22_YP"], axis=1) # 레이블과 무의미한 칼럼 뺌
y = rounded_data[["decisionP"]]

print(X.head())
print(y.head())
# Out:
#    In_22_Size  In_8_Size  In_8_X  In_8_Y  In_8_XP  In_8_YP  In_8_Posion  \
# 0       0.264      0.435  -0.030  -0.918    0.002   -0.926       -0.860
# 1       0.160      0.642   0.299   0.540    0.327    0.572       -0.233
# 2       0.057     -0.185   0.627  -0.116    0.658   -0.118       -0.781
# 3       0.109     -2.044   0.824  -0.626    0.828   -0.598       -0.742
# 4       0.160     -0.598  -0.950   1.414   -0.950    1.379        1.097
#
#    In_8_PosionX  In_8_PosionY  In_8_PosionXB  ...  In_9_Size  In_9_X  In_9_Y  \
# 0         0.903         0.022          0.920  ...     -0.584   0.566  -0.511
# 1        -0.562        -0.327         -0.557  ...     -0.752   0.167  -0.566
# 2         0.171        -0.675          0.146  ...      0.256  -0.367  -0.071
# 3         0.610        -0.814          0.629  ...      0.929   0.500   1.689
# 4        -1.441         0.927         -1.405  ...     -0.416  -0.300   1.194
#
#    In_9_XP  In_9_YP  In_9_P  In_9_PX  In_9_PY  In_9_PXB  In_9_PYB
# ...

# %%
print(X.shape, y.shape)
# Out:
# (2974, 41) (2974, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X, y, stratify=y, random_state=42) # default: test_size=0.25

# %% [markdown]
# # Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint # 통계 라이브러리
from sklearn.neighbors import KNeighborsClassifier

# 랜덤 서치로 n_neighbors 1~50까지 넒게 봄
param_distribs = {'n_neighbors': randint(low=1, high=50)}
random_search=RandomizedSearchCV(KNeighborsClassifier(), param_distributions=param_distribs, cv=5, return_train_score=True, n_iter=20, random_state=1);
random_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print("Best Parameter: {}".format(random_search.best_params_))
print("Best Cross-validity Score: {:.3f}".format(random_search.best_score_))
print("Test set Score: {:.3f}".format(random_search.score(X_test, y_test)))
# Out:
# Best Parameter: {'n_neighbors': 8}
# Best Cross-validity Score: 0.829
# Test set Score: 0.836

# %%
result_random = pd.DataFrame(random_search.cv_results_)
result_random
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005317      0.000841         0.043983        0.001099
# 1        0.004680      0.000128         0.045392        0.002098
# 2        0.005361      0.001194         0.046395        0.006165
# 3        0.005299      0.001096         0.041927        0.000842
# 4        0.005216      0.000662         0.047061        0.001094
# 5        0.005104      0.000727         0.043462        0.001833
# 6        0.006507      0.002017         0.043510        0.002769
# 7        0.005231      0.000710         0.044740        0.002930
# 8        0.006021      0.001043         0.033091        0.003221
# 9        0.005051      0.000596         0.044499        0.002537
# 10       0.005387      0.000622         0.032347        0.000428
# 11       0.005097      0.000601         0.044423        0.002146
# 12       0.004818      0.000509         0.050107        0.006109
# ...

# %%
import matplotlib.pyplot as plt

result_random = result_random.sort_values('param_n_neighbors') # 그래프 x축 순서대로 그려지게
plt.plot(result_random['param_n_neighbors'], result_random['mean_train_score'], label="Train")
plt.plot(result_random['param_n_neighbors'], result_random['mean_test_score'], label="Test")
plt.legend()

# 10 부근이 정확도가 제일 높음 -> 그리드 서치에서 1~20 구간을 돌려봄

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_neighbors' : list(range(1,20)),
    'weights' : ["uniform", "distance"], # default=uniform
    'metric' : ['euclidean', 'manhattan', 'minkowski'] # default=minikowski
}

# %%
from sklearn.neighbors import KNeighborsClassifier
grid_search=GridSearchCV(KNeighborsClassifier(), param_grid, cv=10, return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print("Best Parameter: {}".format(grid_search.best_params_))
print("Best Cross-validity Score: {:.3f}".format(grid_search.best_score_))
print("Test set Score: {:.3f}".format(grid_search.score(X_test, y_test)))
# Out:
# Best Parameter: {'metric': 'euclidean', 'n_neighbors': 4, 'weights': 'distance'}
# Best Cross-validity Score: 0.839
# Test set Score: 0.858

# %%
result_grid= pd.DataFrame(grid_search.cv_results_)
print(result_grid)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.005842      0.001442         0.018324        0.001118
# 1         0.006174      0.000532         0.009867        0.000727
# 2         0.004886      0.000460         0.019943        0.001901
# 3         0.006533      0.000758         0.011191        0.000614
# 4         0.005081      0.000888         0.021471        0.002790
# ..             ...           ...              ...             ...
# 109       0.005103      0.000734         0.016159        0.000474
# 110       0.010621      0.008841         0.042179        0.022719
# 111       0.007067      0.004666         0.025944        0.010909
# 112       0.006019      0.001342         0.038408        0.015795
# 113       0.005898      0.001349         0.026178        0.009645
#
#     param_metric param_n_neighbors param_weights  \
# 0      euclidean                 1       uniform
# 1      euclidean                 1      distance
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.plot(result_grid['param_n_neighbors'], result_grid['mean_train_score'], label="Train")
plt.plot(result_grid['param_n_neighbors'], result_grid['mean_test_score'], label="Test")
plt.legend()

# 파라미터가 여러개이기 때문에 그래프가 왔다갔다하게 나옴.
# 2*3의 경우의 수를 나눠서 그래프를 그리고 싶었지만 시간이 부족해 하지 못함.

# %% [markdown]
# #모델 평가

# %% [markdown]
# ### **** 최종 모델 정확도 ****

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4, weights='distance', metric='euclidean') # distance: 가까이 있는 애가 더 높은 가중치
knn.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix
pred_train=knn.predict(X_train)
confusion_train=confusion_matrix(y_train, pred_train)
print("훈련데이터 오차행렬:\n", confusion_train)

pred_test=knn.predict(X_test)
confusion_test=confusion_matrix(y_test, pred_test)
print("테스트데이터 오차행렬:\n", confusion_test)
print('*** Test Accuracy *** \n   {}'.format(knn.score(X_test, y_test)))

from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
cfreport=classification_report(y_test, pred_test)
print("분류예측 레포트:\n", cfreport)

## 최종 모델 정확도 0.86
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 훈련데이터 오차행렬:
#  [[ 595    0]
#  [   0 1635]]
# 테스트데이터 오차행렬:
#  [[102  96]
#  [ 10 536]]
# *** Test Accuracy ***
#    0.8575268817204301
# 분류예측 레포트:
#                precision    recall  f1-score   support
#
#            0       0.91      0.52      0.66       198
#            1       0.85      0.98      0.91       546
#
#     accuracy                           0.86       744
#    macro avg       0.88      0.75      0.78       744
# weighted avg       0.86      0.86      0.84       744

# %%
f1 = f1_score(y_test, pred_test)
print(f1)

# 최종 모델 fl_score 0.9069 (위의 분류예측 레포트 상에서 row 1, col fl-score 값)
# Out:
# 0.9069373942470389

# %% [markdown]
# ### 이 밑에는 파라미터 바꿔가며 실험해본 결과들입니다.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3, weights='distance', metric='euclidean') # distance: 가까이 있는 애가 더 높은 가중치
knn.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix
pred_train=knn.predict(X_train)
confusion_train=confusion_matrix(y_train, pred_train)
print("훈련데이터 오차행렬:\n", confusion_train)

pred_test=knn.predict(X_test)
confusion_test=confusion_matrix(y_test, pred_test)
print("테스트데이터 오차행렬:\n", confusion_test)
print('*** Test Accuracy *** \n   {}'.format(knn.score(X_test, y_test)))

from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
cfreport=classification_report(y_test, pred_test)
print("분류예측 레포트:\n", cfreport)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 훈련데이터 오차행렬:
#  [[ 595    0]
#  [   0 1635]]
# 테스트데이터 오차행렬:
#  [[ 99  99]
#  [ 10 536]]
# *** Test Accuracy ***
#    0.853494623655914
# 분류예측 레포트:
#                precision    recall  f1-score   support
#
#            0       0.91      0.50      0.64       198
#            1       0.84      0.98      0.91       546
#
#     accuracy                           0.85       744
#    macro avg       0.88      0.74      0.78       744
# weighted avg       0.86      0.85      0.84       744

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3, weights='distance') # distance: 가까이 있는 애가 더 높은 가중치
knn.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix
pred_train=knn.predict(X_train)
confusion_train=confusion_matrix(y_train, pred_train)
print("훈련데이터 오차행렬:\n", confusion_train)

pred_test=knn.predict(X_test)
confusion_test=confusion_matrix(y_test, pred_test)
print("테스트데이터 오차행렬:\n", confusion_test)
print('*** Test Accuracy *** \n   {}'.format(knn.score(X_test, y_test)))

from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
cfreport=classification_report(y_test, pred_test)
print("분류예측 레포트:\n", cfreport)
# Out:
# 훈련데이터 오차행렬:
#  [[ 595    0]
#  [   0 1635]]
# 테스트데이터 오차행렬:
#  [[ 99  99]
#  [ 10 536]]
# *** Test Accuracy ***
#    0.853494623655914
# 분류예측 레포트:
#                precision    recall  f1-score   support
#
#            0       0.91      0.50      0.64       198
#            1       0.84      0.98      0.91       546
#
#     accuracy                           0.85       744
#    macro avg       0.88      0.74      0.78       744
# weighted avg       0.86      0.85      0.84       744
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix
pred_train=knn.predict(X_train)
confusion_train=confusion_matrix(y_train, pred_train)
print("훈련데이터 오차행렬:\n", confusion_train)

pred_test=knn.predict(X_test)
confusion_test=confusion_matrix(y_test, pred_test)
print("테스트데이터 오차행렬:\n", confusion_test)

from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
cfreport=classification_report(y_test, pred_test)
print("분류예측 레포트:\n", cfreport)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 훈련데이터 오차행렬:
#  [[ 413  182]
#  [  21 1614]]
# 테스트데이터 오차행렬:
#  [[ 98 100]
#  [ 10 536]]
# 분류예측 레포트:
#                precision    recall  f1-score   support
#
#            0       0.91      0.49      0.64       198
#            1       0.84      0.98      0.91       546
#
#     accuracy                           0.85       744
#    macro avg       0.88      0.74      0.77       744
# weighted avg       0.86      0.85      0.84       744
